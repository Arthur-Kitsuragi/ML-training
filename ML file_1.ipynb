# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
fig = plt.figure() 
plt.scatter(df['Age'], df['Fare'])
fig.set_figwidth(10)     #  ширина и
fig.set_figheight(10)    #  высота "Figure"

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#df[df['Sex'] == 'female' && df['Age'] > 35] does not work
df1 = df.loc[(df['Sex'] == 'female') & (df['Age'] > 35)].sort_values(by='Age')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 325          326         1       1
# 763          764         1       1
# 387          388         1       2
# 518          519         1       2
# 540          541         1       1
# ..           ...       ...     ...
# 268          269         1       1
# 366          367         1       1
# 829          830         1       1
# 275          276         1       1
# 483          484         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 325                           Young, Miss. Marie Grice  female  36.0      0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 387                                   Buss, Miss. Kate  female  36.0      0
# 518  Angle, Mrs. William A (Florence "Mary" Agnes H...  female  36.0      1
# 540                            Crosby, Miss. Harriet R  female  36.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.to_csv('G:/test_file.csv', index=False)
df2 = pd.read_csv('G:/test_file.csv')
df2
# Out:
#     PassengerId  Survived  Pclass  \
# 0           326         1       1
# 1           764         1       1
# 2           388         1       2
# 3           519         1       2
# 4           541         1       1
# ..          ...       ...     ...
# 68          269         1       1
# 69          367         1       1
# 70          830         1       1
# 71          276         1       1
# 72          484         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                            Young, Miss. Marie Grice  female  36.0      0
# 1           Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 2                                    Buss, Miss. Kate  female  36.0      0
# 3   Angle, Mrs. William A (Florence "Mary" Agnes H...  female  36.0      1
# 4                             Crosby, Miss. Harriet R  female  36.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sns_plot = sns.distplot(df['Age'])
fig = sns_plot.get_figure()

# %%
fig1 = plt.figure() 
df3 = df.sort_values(by='Fare')
plt.plot(df['Age'], df['Fare'])
fig1.set_figwidth(10)     #  ширина и
fig1.set_figheight(10)    #  высота "Figure"
